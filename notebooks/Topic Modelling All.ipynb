# %%
import os
import glob
from tqdm import tqdm

import matplotlib.pyplot as plt
from nltk.tokenize import word_tokenize
import spacy
from spacy import displacy
from top2vec import Top2Vec
from wordcloud import WordCloud, STOPWORDS

from config import Config
from preprocessing.sentiment_analysis import get_sentiment

# %%
model = Top2Vec.load('top2vec_model_deep_all')

# %%
print(f'Number of topics: {model.get_num_topics()}')
# Out:
# Number of topics: 226

# %%
model.get_topics()
# Out:
# (array([['candidates', 'drug', 'pharmaceutical', ..., 'janssen', 'varubi',
#          'biosante'],
#         ['banking', 'deposits', 'bank', ..., 'lcnb', 'institution',
#          'bancorporation'],
#         ['oil', 'drilling', 'gas', ..., 'blowouts', 'unconventional',
#          'explore'],
#         ...,
#         ['airbus', 'aerospace', 'ldw', ..., 'forecasts', 'wheels',
#          'flown'],
#         ['questar', 'wexpro', 'pscw', ..., 'drainage', 'cig',
#          'stipulations'],
#         ['banking', 'noninterest', 'trustmark', ..., 'correspondents',
#          'overdrafts', 'workout']], dtype='<U15'),
#  array([[0.7261023 , 0.64829695, 0.6393302 , ..., 0.45685053, 0.4560685 ,
#          0.45601964],
#         [0.66436505, 0.5713608 , 0.5700095 , ..., 0.37891984, 0.37635577,
#          0.37289983],
#         [0.7492495 , 0.725062  , 0.7078988 , ..., 0.42285335, 0.4209772 ,
#          0.420853  ],
#         ...,
# ...

# %%
model.generate_topic_wordcloud(73, background_color='white')

# %%
model.generate_topic_wordcloud(106, background_color='white')

# %%
model.generate_topic_wordcloud(146, background_color='white')
