# %%
import os
from top2vec import Top2Vec
from wordcloud import WordCloud, STOPWORDS

from config import Config

# %%
model_path = os.path.join(Config.top2vec_models_dir(), 'top2vec_model_phrases')

# %%
def _get_noun_phrases(text):
    pass
model = Top2Vec.load(model_path)

# %%
model.search_documents_by_keywords(keywords=['oil'], num_docs=5)
# Out:
# (array(['You should carefully consider the following risks and all of the information contained in this Report. Our\nbusiness, financial condition, and results of operations could be materially and adversely affected by any of these risks. The risks described below are not the only ones facing us. Additional risks\nnot presently known to us or which we consider immaterial also may adversely affect us.Our business is difficult to evaluate because we have a limited operating history.Athlon Energy Inc. was formed in April 2013 and became the majority owner of Athlon Holdings LP and its subsidiaries,\nwhich began operating our first properties after acquiring them in January 2011. As a result, there is only limited historical financial and operating information available upon which to base your\nevaluation of our performance.Drilling for and producing oil and natural gas are high-risk activities with many uncertainties that may result in a total loss of investment or otherwise adversely 
# ...

# %%
model.get_topics()
# Out:
# (array([['oil', 'drilling', 'oil and gas property', ...,
#          'exploratory well', 'dry hole',
#          'future oil and natural gas production'],
#         ['software product', 'software industry', 'software', ...,
#          'professional service revenue', 'license sale',
#          'microsoft office'],
#         ['semiconductor product', 'semiconductor',
#          'semiconductor industry', ..., 'advanced process technology',
#          'process technology', 'reduced manufacturing yield'],
#         ...,
#         ['insurance operate unit', 'bovie', 'insurance operating unit',
#          ..., 'underwriting organization', 'reinsurance recoverable',
#          'property and casualty insurance subsidiary'],
#         ['policyholder', 'oil and gas production', 'deepwater gulf', ...,
#          'relatively short production period', 'oil and gas asset',
#          'well'],
#         ['argo group', 'argo', 'argo re', ..., 'ipc holdings',
# ...

# %%
model.hierarchical_topic_reduction(num_topics=50)
# Out:
# [[189,
#   59,
#   293,
#   58,
#   161,
#   155,
#   311,
#   77,
#   399,
#   445,
#   128,
#   410,
#   290,
#   421,
#   255,
#   245,
#   482,
#   319,
#   159,
#   489,
#   422,
#   508,
#   106],
#  [434, 42, 356, 401, 551, 269, 371, 275, 299, 304, 363, 418, 547, 561, 0],
#  [78,
#   116,
#   102,
#   511,
#   49,
#   448,
#   100,
#   270,
#   199,
#   258,
#   303,
#   510,
#   166,
#   428,
#   99,
#   198,
#   178,
#   308,
#   296,
#   408,
#   7],
#  [229,
#   272,
#   469,
#   95,
#   25,
#   468,
#   80,
#   110,
#   93,
#   147,
#   143,
#   168,
#   181,
#   247,
#   280,
#   347,
#   383,
#   499,
#   9],
#  [390,
#   218,
#   36,
#   387,
#   259,
#   456,
#   68,
#   500,
#   231,
#   121,
#   139,
#   548,
#   86,
#   297,
#   111,
#   169,
#   227,
#   246,
#   295,
#   238,
#   324,
#   50],
#  [252, 518, 48, 165, 180, 460, 541, 1],
#  [317,
#   447,
#   138,
#   154,
#   307,
#   129,
#   491,
#   153,
#   90,
#   281,
#   503,
#   530,
#   148,
#   516,
# ...

# %%
model.get_topics(reduced=True)
# Out:
# (array([['global business', 'global operation', 'low - cost country', ...,
#          'lydall', 'titanium dioxide', 'legal compliance risk'],
#         ['oil', 'exploration', 'drilling', ...,
#          'oil and natural gas activity',
#          'oil and natural gas exploration and production activity',
#          'oil and natural gas business'],
#         ['current and prospective customer', 'hardware product',
#          'operating result', ..., 'sale opportunity', 'solution',
#          'telecommunications industry'],
#         ...,
#         ['transportation industry', 'trucking industry',
#          'qualified driver', ..., 'truckload service', 'eligible driver',
#          'driver wage'],
#         ['store location', 'store', 'qualified team member', ...,
#          'natural food store', 'team members',
#          'management and team member'],
#         ['dealership', 'vehicle sale', 'new vehicle', ...,
#          'repossess vehicle', 'service center chain store',
# ...

# %%
model.generate_topic_wordcloud(10, background_color='white', reduced=True)
