# %%
from risk_detection.analysis.clustering import analyze_yearly_clusters, read_yearly_cluster

# %%
_, cl = read_yearly_cluster(2008)

# %%
new_clusters = analyze_yearly_clusters(print_matched=False, print_unmatched=False)
# Out:
# Average Number of Yearly Clusters: 6517.307692307692
# Average Number of Words in Yearly Clusters: 11.567813514311005
# Average number of Yearly Matches Found: 5406.846153846154

# %%
print(new_clusters[2015][1])
# Out:
# [['a charge', 'additional subpoenas', 'amended consolidated class action complaint', 'charges due', 'claims due', 'enforcements proceedings', 'petition amounts', 'petition claims', 'recurring charges', 'us federal grand jury subpoenas', 'various prudence proceedings', 'various qsrs alleging'], ['electronic display industry', 'full color led video displays capable', 'full color pixels capable', 'full matrix outdoor displays capable', 'graphics display systems', 'higher average selling price flat panel display systems', 'large electronic display systems', 'large electronic displays', 'large format display needs', 'large format electronic display industry', 'large integrated display systems sales', 'large integrated system sales', 'larger display system installations', '® full matrix displays'], ['transaction approval requirements', 'transaction specific risks', 'transactional requirements applicable', 'transactions include difficulties', 'transmission congestion price risks', 'transmis
# ...
