# %%
import glob
import os

from rake_nltk import Rake
from tqdm import tqdm

from config import Config

# %%
rake = Rake(max_length=3)

# %%
keywords_1 = {}
for risk_file in tqdm(glob.glob(os.path.join(Config.risk_dir() + '_old', 'appl_risk', '*.txt'))):
    with open(risk_file) as f:
        doc = f.read()
    rake.extract_keywords_from_text(doc)
    keywords_1[risk_file] = rake.get_ranked_phrases()
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 9/9 [00:00<00:00, 33.50it/s]

# %%
keywords
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-1eb9771c7f0a> in <module>
# ----> 1 keywords
#
# NameError: name 'keywords' is not defined

# %%
keywords_1
# Out:
# {'c:\\machine_learning\\10k-emerging-risk-detection\\data\\risk_section_old\\appl_risk\\0001047469-07-009340.txt': ['united states attorney',
#   'trend toward consolidation',
#   'promote brand awareness',
#   'permanent injunction prohibiting',
#   'environmentally safe disposal',
#   'changed circumstances indicate',
#   'materially adversely impacted',
#   'fiscal year 2008',
#   'calendar year 2006',
#   'material adverse impact',
#   'supplementary data ,"',
#   'class action complaint',
#   'acceptable usage rules',
#   'may propose legislation',
#   'insured limits may',
#   'digital music devices',
#   'two former officers',
#   'foreign subsidiaries ),',
#   'foreign exchange rates',
#   'foreign exchange forward',
#   'executive officers pertaining',
#   '2006 form 10',
#   'materially adversely affect',
#   'general retail activity',
#   'enhance reseller sales',
#   'accrues necessary reserves',
#   'prior financial statements',
#   'consolidated financial statements',
# ...
